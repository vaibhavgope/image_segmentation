# %% [markdown]
# # Segmentation of Indian Traffic

# %%
import math
from PIL import Image, ImageDraw
from PIL import ImagePath
import pandas as pd
import os
from os import path
from tqdm.notebook import tqdm
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt
import urllib
import json
import imgaug.augmenters as iaa
import datetime

# %% [markdown]
# # Task 1: Preprocessing

# %% [markdown]
# ## 1. Get all the file name and corresponding json files

# %%
def return_file_names_df(root_dir):
    root_dir = 'data'
    img_path = root_dir+"/images"
    mask_path = root_dir+'/mask'
    file_names_images = list()
    file_names_masks =list()
    for scene in os.listdir(img_path):
        mask_dir = [i for i in os.listdir(mask_path+'/'+scene)]
        for i in os.listdir(img_path+'/'+scene):
            to_find = i.split('_')[0]
            mask = list(filter(lambda x: to_find in x, mask_dir))[0]
            file_names_images.append(img_path+'/'+scene+'/'+i)
            file_names_masks.append(mask_path+'/'+scene+'/'+mask)

    data_df = pd.DataFrame(list(zip(file_names_images, file_names_masks)), 
               columns =['images', 'json']) 
    return data_df

# %%
data_df = return_file_names_df('data')
data_df.head()
# Out:
#                                       images  \
# 0  data/images/201/frame0029_leftImg8bit.jpg
# 1  data/images/201/frame0299_leftImg8bit.jpg
# 2  data/images/201/frame0779_leftImg8bit.jpg
# 3  data/images/201/frame1019_leftImg8bit.jpg
# 4  data/images/201/frame1469_leftImg8bit.jpg
#
#                                            json
# 0  data/mask/201/frame0029_gtFine_polygons.json
# 1  data/mask/201/frame0299_gtFine_polygons.json
# 2  data/mask/201/frame0779_gtFine_polygons.json
# 3  data/mask/201/frame1019_gtFine_polygons.json
# 4  data/mask/201/frame1469_gtFine_polygons.json

# %%
data_df.shape
# Out:
# (4007, 2)

# %% [markdown]
# #### Compute the unique labels

# %%
import json
def return_unique_labels(data_df):
    unique_labels = set()
    for mask in data_df['json']:
        f = open(mask,) 
        data = json.load(f)
        for i in data['objects']:
            unique_labels.add(i['label'])
        f.close()
    return unique_labels

# %%
unique_labels = return_unique_labels(data_df)
len(unique_labels)
# Out:
# 40

# %%
label_clr = {'road':10, 'parking':20, 'drivable fallback':20,'sidewalk':30,'non-drivable fallback':40,'rail track':40,\
                        'person':50, 'animal':50, 'rider':60, 'motorcycle':70, 'bicycle':70, 'autorickshaw':80,\
                        'car':80, 'truck':90, 'bus':90, 'vehicle fallback':90, 'trailer':90, 'caravan':90,\
                        'curb':100, 'wall':100, 'fence':110,'guard rail':110, 'billboard':120,'traffic sign':120,\
                        'traffic light':120, 'pole':130, 'polegroup':130, 'obs-str-bar-fallback':130,'building':140,\
                        'bridge':140,'tunnel':140, 'vegetation':150, 'sky':160, 'fallback background':160,'unlabeled':0,\
                        'out of roi':0, 'ego vehicle':180, 'ground':190,'rectification border':200,\
                   'train':210}

# %% [markdown]
# ## 3. Extracting the polygons from the json files

# %%
def get_poly(mask):
    f = open(mask,) 
    data = json.load(f)
    labels = []
    for i in data['objects']:
        labels.append(i['label'])
    vertexList = []
    for i in data['objects']:
        vertexList.append([(k[0],k[1]) for k in i['polygon']])
   
    # width of the image
    w = data['imgWidth']
    # height of the image
    h = data['imgHeight']
    f.close()
    return w, h, labels, vertexList

# %%
def grader_3(file):
    w, h, labels, vertexlist = get_poly(file)
    print(len((set(labels)))==18 and len(vertexlist)==227 and w==1920 and h==1080 \
          and isinstance(vertexlist,list) and isinstance(vertexlist[0],list) and isinstance(vertexlist[0][0],tuple) )

grader_3('data/mask/201/frame0029_gtFine_polygons.json')
# Out:
# True

# %% [markdown]
# ## 4. Creating Image segmentations by drawing set of polygons

# %%
import math 
from PIL import Image, ImageDraw 
from PIL import ImagePath
from pathlib import Path

# %%
def compute_masks(data_df):
    new_df = data_df.copy()
    masks = []
    for i in data_df['json']:
        w, h, label, vertexlist = get_poly(i)
        img = Image.new("RGB", (w, h))
        img1 = ImageDraw.Draw(img)
        for j in range(len(vertexlist)):
            try:
                img1.polygon(vertexlist[j], fill = label_clr[label[j]])
            except TypeError:
                continue
        img=np.array(img)

        path = i.split('/')
        Path(path[0]+'/output/'+path[2]).mkdir(parents=True, exist_ok=True)
        path = path[0]+'/output/'+path[2]+'/'+path[-1].split('.')[0]+'.png'
        masks.append(path)
        im = Image.fromarray(img[:,:,0])
        im.save(path,'PNG')

    new_df['mask'] = masks
    return new_df

# %%
data_df = compute_masks(data_df)
data_df.head()
# Out:
#                                       images  \
# 0  data/images/201/frame0029_leftImg8bit.jpg
# 1  data/images/201/frame0299_leftImg8bit.jpg
# 2  data/images/201/frame0779_leftImg8bit.jpg
# 3  data/images/201/frame1019_leftImg8bit.jpg
# 4  data/images/201/frame1469_leftImg8bit.jpg
#
#                                            json  \
# 0  data/mask/201/frame0029_gtFine_polygons.json
# 1  data/mask/201/frame0299_gtFine_polygons.json
# 2  data/mask/201/frame0779_gtFine_polygons.json
# 3  data/mask/201/frame1019_gtFine_polygons.json
# 4  data/mask/201/frame1469_gtFine_polygons.json
#
#                                             mask
# 0  data/output/201/frame0029_gtFine_polygons.png
# 1  data/output/201/frame0299_gtFine_polygons.png
# 2  data/output/201/frame0779_gtFine_polygons.png
# 3  data/output/201/frame1019_gtFine_polygons.png
# 4  data/output/201/frame1469_gtFine_polygons.png

# %%
def resize_images(dir):
    for item in dir:
        if os.path.isfile(item):
            im = Image.open(item)
            imResize = im.resize((256,256), Image.ANTIALIAS)
            imResize.save(item, 'JPEG', quality=90)
resize_images(data_df['images'])
resize_images(data_df['mask'])

# %% [markdown]
# ### Task 2.1: Dice loss

# %% [markdown]
# ### Task 2.2: Training Unet

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_df['images'],data_df['mask'], test_size=0.2, random_state=42)

# %%
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Multiply
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

import segmentation_models as sm
from segmentation_models.metrics import iou_score
from segmentation_models import Unet
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
aug2 = iaa.Fliplr(1)
aug3 = iaa.Flipud(1)
aug4 = iaa.Emboss(alpha=(1), strength=1)
aug5 = iaa.DirectedEdgeDetect(alpha=(0.8), direction=(1.0))
aug6 = iaa.Sharpen(alpha=(1.0), lightness=(1.5))

# %%
def visualize(**images):
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        if i==1:
            plt.imshow(image, cmap='gray', vmax=1, vmin=0)
        else:
            plt.imshow(image)
    plt.show()
    
class Dataset:
    def __init__(self, image_ids, mask_ids, augment=False):
        
        self.ids = image_ids
        self.mask_ids = mask_ids
        # the paths of images
        self.images_fps   = [image_id for image_id in self.ids]
        # the paths of segmentation images
        self.masks_fps    = [image_id for image_id in self.mask_ids]
        self.augment = augment
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i], cv2.IMREAD_UNCHANGED)
        mask  = cv2.imread(self.masks_fps[i], cv2.IMREAD_UNCHANGED)
        #normalizing mask
        mask = mask//10

        image_masks = [(mask == v) for v in np.arange(0,21,1)]
        image_mask = np.stack(image_masks, axis=-1).astype('float')

        if self.augment:
            a = np.random.uniform()
            if a<0.2:
                image = aug2.augment_image(image)
                image_mask = aug2.augment_image(image_mask)
            elif a<0.4:
                image = aug3.augment_image(image)
                image_mask = aug3.augment_image(image_mask)
            elif a<0.6:
                image = aug4.augment_image(image)
                image_mask = aug4.augment_image(image_mask)
            elif a<0.8:
                image = aug5.augment_image(image)
                image_mask = image_mask
            else:
                image = aug6.augment_image(image)
                image_mask = aug6.augment_image(image_mask)
            
        return image, image_mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(tf.keras.utils.Sequence):    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return tuple(batch)
    
    def __len__(self):
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
train_dataset = Dataset(X_train,y_train, augment=False)
train_dataloader = Dataloder(train_dataset, batch_size=8, shuffle=True)

test_dataset = Dataset(X_test,y_test)
test_dataloader = Dataloder(test_dataset, batch_size=8, shuffle=False)

# %%
optim = keras.optimizers.RMSprop(lr=0.00001)

focal_loss = sm.losses.cce_dice_loss
model = Unet('resnet34',classes=21, activation='softmax',input_shape=(256,256,3),encoder_weights='imagenet')

model.compile(optim, focal_loss, metrics=[iou_score])

# %%
model.load_weights('unet_2.h5')

# %%
# this was trained with a batch size of 8 on 256*256 images
history = model.fit(train_dataloader, steps_per_epoch=len(train_dataloader), epochs=500,\
                              validation_data=test_dataloader)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 400 steps, validate for 100 steps
# Epoch 1/500
# 400/400 [==============================] - 159s 397ms/step - loss: 0.5049 - iou_score: 0.4189 - val_loss: 0.5745 - val_iou_score: 0.3667
# Epoch 2/500
# 400/400 [==============================] - 151s 378ms/step - loss: 0.4972 - iou_score: 0.4241 - val_loss: 0.5741 - val_iou_score: 0.3662
# Epoch 3/500
# 400/400 [==============================] - 151s 378ms/step - loss: 0.
500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3730 - iou_score: 0.5429 - val_loss: 0.5883 - val_iou_score: 0.3713
# Epoch 447/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3727 - iou_score: 0.5432 - val_loss: 0.5890 - val_iou_score: 0.3708
# Epoch 448/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3728 - iou_score: 0.5431 - val_loss: 0.5894 - val_iou_score: 0.3703
# Epoch 449/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3726 - iou_score: 0.5433 - val_loss: 0.5888 - val_iou_score: 0.3709
# Epoch 450/500
# 400/400 [==============================] - 155s 387ms/step - loss: 0.3723 - iou_score: 0.5437 - val_loss: 0.5889 - val_iou_score: 0.3709
# Epoch 451/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3727 - iou_score: 0.5432 - val_loss: 0.5898 - val_iou_score: 0.3700
# Epoch 452/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3724 - iou_score: 0.5436 - val_loss: 0.5890 - val_iou_score: 0.3707
# Epoch 453/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3724 - iou_score: 0.5435 - val_loss: 0.5891 - val_iou_score: 0.3707
# Epoch 454/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3723 - iou_score: 0.5436 - val_loss: 0.5894 - val_iou_score: 0.3703
# Epoch 455/500
# 400/400 [==============================] - 155s 387ms/step - loss: 0.3724 - iou_score: 0.5436 - val_loss: 0.5898 - val_iou_score: 0.3700
# Epoch 456/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3723 - iou_score: 0.5437 - val_loss: 0.5883 - val_iou_score: 0.3716
# Epoch 457/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3723 - iou_score: 0.5436 - val_loss: 0.5888 - val_iou_score: 0.3711
# Epoch 458/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3722 - iou_score: 0.5438 - val_loss: 0.5887 - val_iou_score: 0.3712
# Epoch 459/500
# 400/400 [==============================] - 155s 388ms/step - loss: 0.3722 - iou_score: 0.5438 - val_loss: 0.5896 - val_iou_score: 0.3703
# Epoch 460/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3720 - iou_score: 0.5439 - val_loss: 0.5882 - val_iou_score: 0.3719
# Epoch 461/500
# 400/400 [==============================] - 154s 386ms/step - loss: 0.3720 - iou_score: 0.5440 - val_loss: 0.5891 - val_iou_score: 0.3710
# Epoch 462/500
# 400/400 [==============================] - 156s 391ms/step - loss: 0.3719 - iou_score: 0.5441 - val_loss: 0.5889 - val_iou_score: 0.3712
# Epoch 463/500
# 400/400 [==============================] - 152s 380ms/step - loss: 0.3718 - iou_score: 0.5442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-a4ee75316ca3> in <module>
#       1 # this was trained with a batch size of 8 on 256*256 images
#       2 history = model.fit(train_dataloader, steps_per_epoch=len(train_dataloader), epochs=500,\
# ----> 3                               validation_data=test_dataloader)
#
# D:\Installed\Anaconda3\envs\venv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# D:\Installed\Anaconda3\envs\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     393                       mode=ModeKeys.TEST,
#     394                       training_context=eval_context,
# --> 395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
#     397                                  prefix='val_')
#
# D:\Installed\Anaconda3\envs\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# D:\Installed\Anaconda3\envs\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# D:\Installed\Anaconda3\envs\venv\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     505
#     506
# --> 507 @tf_export("nest.map_structure")
#     508 def map_structure(func, *structure, **kwargs):
#     509   """Applies `func` to each entry in `structure` and returns a new structure.
#
# KeyboardInterrupt:

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.load_weights('unet_2.h5')

# %%
for i,m in zip(X_test[:10],y_test[:10]):
    #original image
    image = cv2.imread(i, cv2.IMREAD_UNCHANGED)
    image = cv2.resize(image, (256,256)) 
    
    #predicted segmentation map
    predicted  = model.predict(image[np.newaxis,:,:,:])
    
    #original segmentation map
    image_mask = cv2.imread(m, cv2.IMREAD_UNCHANGED)
    print(m)
    image_mask = cv2.resize(image_mask, (256,256))

    plt.figure(figsize=(10,6))
    plt.subplot(131)
    plt.imshow(image)
    plt.subplot(132)
    plt.imshow(image_mask)
    plt.subplot(133)
    plt.imshow(predicted[0,:,:,0], cmap='gray', vmax=1, vmin=0)
    plt.show()
# Out:
# data/output/275/frame10480_gtFine_polygons.png
# data/output/327/frame1124_gtFine_polygons.png
# data/output/400/frame0595_gtFine_polygons.png
# data/output/361/frame8692_gtFine_polygons.png
# data/output/357/frame27932_gtFine_polygons.png
# data/output/263/frame19513_gtFine_polygons.png
# data/output/233/frame1002_gtFine_polygons.png
# data/output/213/frame18369_gtFine_polygons.png
# data/output/377/frame15853_gtFine_polygons.png
# data/output/387/frame5281_gtFine_polygons.png

# %% [markdown]
# # Task 3: Training CANet

# %%
class convolutional_block(tf.keras.layers.Layer):
    def __init__(self, kernel=3,  filters=[4,4,8], stride=1, name="conv_block"):
        super().__init__(name=name)
        self.F1, self.F2, self.F3 = filters
        self.kernel = kernel
        self.stride = stride
        self.conv1 = Conv2D(self.F1, (1, 1), strides = (1,1),kernel_initializer='glorot_uniform',activation='relu')
        self.bn1 = BatchNormalization()
        self.act1 = Activation('relu')

        self.conv2 = Conv2D(self.F2, (self.kernel,self.kernel), strides = (self.stride,self.stride), padding = 'same',kernel_initializer='glorot_uniform',activation='relu')
        self.bn2 = BatchNormalization()
        self.act2 = Activation('relu')

        self.conv3 = Conv2D(self.F3, (1, 1), strides = (1,1),kernel_initializer='glorot_uniform',activation='relu')
        self.bn3 = BatchNormalization()
        self.act3 = Activation('relu')

        self.conv4 = Conv2D(self.F3, (1,1), strides = (self.stride,self.stride),kernel_initializer='glorot_uniform',activation='relu')
        self.bn4 = BatchNormalization()
        self.add = Add()
        self.act4 = Activation('relu')
    def call(self, X):
        # copy of input to use later
        X_second = tf.identity(X)

        X = self.conv1(X)
        X = self.bn1(X)
        X = self.act1(X)

        X = self.conv2(X)
        X = self.bn2(X)
        X = self.act2(X)


        X = self.conv3(X)
        X = self.bn3(X)
        X = self.act3(X)

        #Other path
        X_second = self.conv4(X_second)
        X_second = self.bn4(X_second)
        X = self.add([X, X_second])
        X = self.act4(X)
        return X

# %%
class identity_block(tf.keras.layers.Layer):
    def __init__(self, kernel=3,  filters=[4,4,8], name="identity_block"):
        super().__init__(name=name)
        self.F1, self.F2, self.F3 = filters
        self.kernel = kernel
        self.conv1 = Conv2D(self.F1, (1, 1), strides = (1,1),kernel_initializer='he_uniform',activation='relu')
        self.bn1 = BatchNormalization()
        self.act1 =  Activation('relu')
        self.conv2 = Conv2D(self.F2, (self.kernel, self.kernel), strides = (1,1), padding = 'same',kernel_initializer='glorot_uniform',activation='relu')
        self.bn2 = BatchNormalization()
        self.act2 =  Activation('relu')
        self.conv3 = Conv2D(self.F3, (self.kernel, self.kernel), strides = (1,1),padding = 'same',kernel_initializer='glorot_uniform',activation='relu')
        self.bn3 = BatchNormalization()
        self.act3 =  Activation('relu')
        self.add = Add()
        self.act4 =  Activation('relu')

    def call(self, X):
        # copy of input to use later
        X_second = tf.identity(X)
    
        X = self.conv1(X)
        X = self.bn1(X)
        X = self.act1(X)

        X = self.conv2(X)
        X = self.bn2(X)
        X = self.act2(X)

        X = self.conv3(X)
        X = self.bn3(X)
        X = self.act3(X)

        X = self.add([X, X_second])
        X = self.act4(X)
        return X

# %%
class global_flow(tf.keras.layers.Layer):
    def __init__(self, name="global_flow"):
        super().__init__(name=name)
        self.pool = GlobalAveragePooling2D()
        self.reshape = tf.keras.layers.Reshape((1,1,64))
        self.bn = BatchNormalization()
        self.act = Activation('relu')
        self.conv = Conv2D(32, (1, 1), activation = 'relu', padding = 'same',name='conv_before_transpose',kernel_initializer='glorot_uniform')
        self.upsample = UpSampling2D(size=(32, 32), interpolation='bilinear')
    def call(self, X):
        X = self.pool(X)
        X = self.reshape(X)
        X = self.bn(X)
        X = self.act(X)
        X = self.conv(X)
        X = self.upsample(X)
        return X

# %%
class context_flow(tf.keras.layers.Layer):    
    def __init__(self, name="context_flow"):
        super().__init__(name=name)
        self.conc = Concatenate(axis=-1)
        self.avg_pool = AveragePooling2D((2, 2), (2, 2))
        self.conv1 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same',kernel_initializer='glorot_uniform')
        self.conv2 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same',kernel_initializer='glorot_uniform')
        self.conv3 = Conv2D(32, (1, 1), activation = 'relu', padding = 'same',kernel_initializer='glorot_uniform')
        self.act1 = Activation('relu')
        self.conv4 = Conv2D(32, (1, 1), activation = 'relu', padding = 'same',kernel_initializer='glorot_uniform')
        self.act2 =  Activation('sigmoid')
        self.mul = Multiply()
        self.add = Add()
        self.upsample = UpSampling2D(size=(2, 2), interpolation='bilinear')
    def call(self, X):
        INP, FLOW = X[0], X[1]

        X = self.conc([INP,FLOW])
        X = self.avg_pool(X)
        X = self.conv1(X)
        X = self.conv2(X)
        Conv1 = self.conv3(X)
        rel = self.act1(Conv1)
        Conv2 = self.conv4(rel)
        sig =  self.act2(Conv2)
        X_2 = self.mul([X , sig])
        X = self.add([X,X_2])
        X = self.upsample(X)
        return X

# %%
class fsm(tf.keras.layers.Layer):    
    def __init__(self, name="feature_selection"):
        super().__init__(name=name)
        self.conv1 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same',name='fs_conv_1',kernel_initializer='glorot_uniform')
        self.global_pool = GlobalAveragePooling2D(name='global_pool')
        self.reshape = tf.keras.layers.Reshape((1,1,32))
        self.conv2 = Conv2D(32, (1, 1), activation = 'relu', padding = 'same',name='fs_conv_2',kernel_initializer='glorot_uniform')
        self.bn = BatchNormalization()
        self.act = Activation('sigmoid')
        self.mul = Multiply(name='fs_mul')
        self.upsample = UpSampling2D(size=(2, 2), interpolation='bilinear')
    def call(self, X):
        Conv_1 = self.conv1(X)
        X = self.global_pool(Conv_1)
        X = self.reshape(X)
        X = self.conv2(X)
        X = self.bn(X)
        X = self.act(X)
        X = self.mul([Conv_1,X])
        X = self.upsample(X)
        return X

# %%
class agcn(tf.keras.layers.Layer):    
    def __init__(self, name="global_conv_net"):
        super().__init__(name=name)
        self.conv1 = Conv2D(32, (7, 1), activation = 'relu', padding = 'same')
        self.conv2 = Conv2D(32, (1, 7), activation = 'relu', padding = 'same')

        self.conv3 = Conv2D(32, (1, 7), activation = 'relu', padding = 'same')
        self.conv4 = Conv2D(32, (7, 1), activation = 'relu', padding = 'same')

        self.add = Add()

        self.conv5 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same')

        self.out = Add()
        
    def call(self, X):
        Conv1 = self.conv1(X)
        Conv1 = self.conv2(Conv1)

        Conv2 = self.conv3(X)
        Conv2 = self.conv4(Conv2)

        O1 = self.add([Conv1,Conv2])

        Conv3 = self.conv5(O1)

        output = self.out([O1,Conv3])
        return output
# he uniform, different optim,

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, 
                                   verbose=1, mode='max', min_delta=0.0001, cooldown=2, min_lr=1e-5 )

# %%
#new architecture
inp = Input((256,256,3))
X = Conv2D(64,(1,1),activation='relu')(inp)
X = BatchNormalization(momentum=0.9, epsilon=0.1)(X)
X = Activation('relu')(X)
X = MaxPooling2D()(X)
# C1
Conv_block = convolutional_block(kernel=3, filters=[4, 4, 8], stride=2,name='first_conv_block')
C1 = Conv_block(X)
identity = identity_block(3, [4, 4, 8], name='first_identity')
X = identity(C1)

# C2
Conv_block = convolutional_block(kernel=3, filters=[8, 8, 16], stride=2,name='second_conv_block')
C2 = Conv_block(X)
identity = identity_block(3, [8, 8, 16], name='second_identity_a')
X = identity(C2)
identity = identity_block(3, [8, 8, 16], name='second_identity_b')
X = identity(X)

# C3
Conv_block = convolutional_block(kernel=3, filters=[16, 16, 32], stride=1,name='third_conv_block')
C3 = Conv_block(X)
identity = identity_block(3, [16, 16, 32], name='third_identity_a')
X = identity(C3)
identity = identity_block(3, [16, 16, 32], name='third_identity_b')
X = identity(X)
identity = identity_block(3, [16, 16, 32], name='third_identity_c')
X = identity(X)

# C4
Conv_block = convolutional_block(kernel=3, filters=[32, 32, 64], stride=1,name='fourth_conv_block')
C4 = Conv_block(X)
identity = identity_block(3, [32, 32, 64], name='fourth_identity_a')
X = identity(C4)
identity = identity_block(3, [32, 32, 64], name='fourth_identity_b')
X = identity(X)
identity = identity_block(3, [32, 32, 64], name='fourth_identity_c')
X = identity(X)
identity = identity_block(3, [32, 32, 64], name='fourth_identity_d')
X = identity(X)
GF = global_flow()
global_output = GF(X)

CF = context_flow(name='context_flow_1')

CF_1 = CF([X,global_output])
CF = context_flow(name='context_flow_2')
CF_2 = CF([X,CF_1])
CF = context_flow(name='context_flow_3')
CF_3 = CF([X,CF_2])

cf_out = Add(name = 'add_cf_gf')([global_output, CF_1, CF_2, CF_3])

FSM = fsm()
fs_out = FSM(cf_out)
AGCN = agcn()
ag_out = AGCN(C1)
out = concatenate([fs_out,ag_out],axis=-1)

final = Conv2D(21, (3, 3), activation = 'relu', padding = 'same', name = 'final_conv')(out)

final_upsample = UpSampling2D(size=(4, 4), interpolation='bilinear')(final)

output = (Activation('softmax'))(final_upsample)
model = Model(inputs = inp, outputs = output)

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 256         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# first_conv_block (convolutional (None, 64, 64, 8)    1064        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# first_identity (identity_block) (None, 64, 64, 8)    544         first_conv_block[0][0]
# __________________________________________________________________________________________________
# second_conv_block (convolutiona (None, 32, 32, 16)   1136        first_identity[0][0]
# __________________________________________________________________________________________________
# second_identity_a (identity_blo (None, 32, 32, 16)   2016        second_conv_block[0][0]
# __________________________________________________________________________________________________
# second_identity_b (identity_blo (None, 32, 32, 16)   2016        second_identity_a[0][0]
# __________________________________________________________________________________________________
# third_conv_block (convolutional (None, 32, 32, 32)   4064        second_identity_b[0][0]
# __________________________________________________________________________________________________
# third_identity_a (identity_bloc (None, 32, 32, 32)   7744        third_conv_block[0][0]
# __________________________________________________________________________________________________
# third_identity_b (identity_bloc (None, 32, 32, 32)   7744        third_identity_a[0][0]
# __________________________________________________________________________________________________
# third_identity_c (identity_bloc (None, 32, 32, 32)   7744        third_identity_b[0][0]
# __________________________________________________________________________________________________
# fourth_conv_block (convolutiona (None, 32, 32, 64)   15296       third_identity_c[0][0]
# __________________________________________________________________________________________________
# fourth_identity_a (identity_blo (None, 32, 32, 64)   30336       fourth_conv_block[0][0]
# __________________________________________________________________________________________________
# fourth_identity_b (identity_blo (None, 32, 32, 64)   30336       fourth_identity_a[0][0]
# __________________________________________________________________________________________________
# fourth_identity_c (identity_blo (None, 32, 32, 64)   30336       fourth_identity_b[0][0]
# __________________________________________________________________________________________________
# fourth_identity_d (identity_blo (None, 32, 32, 64)   30336       fourth_identity_c[0][0]
# __________________________________________________________________________________________________
# global_flow (global_flow)       (None, 32, 32, 32)   2336        fourth_identity_d[0][0]
# __________________________________________________________________________________________________
# context_flow_1 (context_flow)   (None, 32, 32, 32)   39040       fourth_identity_d[0][0]
#                                                                  global_flow[0][0]
# __________________________________________________________________________________________________
# context_flow_2 (context_flow)   (None, 32, 32, 32)   39040       fourth_identity_d[0][0]
#                                                                  context_flow_1[0][0]
# __________________________________________________________________________________________________
# context_flow_3 (context_flow)   (None, 32, 32, 32)   39040       fourth_identity_d[0][0]
#                                                                  context_flow_2[0][0]
# __________________________________________________________________________________________________
# add_cf_gf (Add)                 (None, 32, 32, 32)   0           global_flow[0][0]
#                                                                  context_flow_1[0][0]
#                                                                  context_flow_2[0][0]
#                                                                  context_flow_3[0][0]
# __________________________________________________________________________________________________
# feature_selection (fsm)         (None, 64, 64, 32)   10432       add_cf_gf[0][0]
# __________________________________________________________________________________________________
# global_conv_net (agcn)          (None, 64, 64, 32)   27296       first_conv_block[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           feature_selection[0][0]
#                                                                  global_conv_net[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 64, 64, 21)   12117       concatenate_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 21) 0           final_conv[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 256, 256, 21) 0           up_sampling2d_5[0][0]
# ==================================================================================================
# Total params: 340,525
# Trainable params: 337,917
# Non-trainable params: 2,608
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model4.png', show_shapes=True, show_layer_names=True,
    rankdir='TB')
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
model.load_weights('segmentation_final.h5')

# %%
optim = tf.keras.optimizers.RMSprop(learning_rate=1e-4)

focal_loss = sm.losses.cce_dice_loss

model.compile(optim, focal_loss, metrics=[iou_score])

# %%
# trained on full dataset with 512*512 images
history = model.fit(train_dataloader, steps_per_epoch=len(train_dataloader), epochs=300,\
                    validation_data=test_dataloader,callbacks=[reduceLROnPlat],validation_steps=len(test_dataloader))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 100 steps, validate for 25 steps
# Epoch 1/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5866 - iou_score: 0.3505 - val_loss: 0.7463 - val_iou_score: 0.2359
# Epoch 2/300
# 100/100 [==============================] - 82s 815ms/step - loss: 0.5866 - iou_score: 0.3506 - val_loss: 0.7448 - val_iou_score: 0.2371
# Epoch 3/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5866 - iou_score: 0.3506 - val_loss: 0.7479 - val_iou_score: 0.2348
# Epoch 4/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5865 - iou_score: 0.3507 - val_loss: 0.7468 - val_iou_score: 0.2356
# Epoch 5/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5865 - iou_score: 0.3507 - val_loss: 0.7448 - val_iou_score: 0.2368
# Epoch 6/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5864 - iou_score: 0.3507 - val_loss: 0.7440 - val_iou_score: 0.2376
# Epoch 7/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5864 - iou_score: 0.3508 - val_loss: 0.7468 - val_iou_score: 0.2360
# Epoch 8/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5863 - iou_score: 0.3508 - val_loss: 0.7457 - val_iou_score: 0.2367
# Epoch 9/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5863 - iou_score: 0.3509 - val_loss: 0.7469 - val_iou_score: 0.2355
# Epoch 10/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5862 - iou_score: 0.3509 - val_loss: 0.7456 - val_iou_score: 0.2364
# Epoch 11/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5862 - iou_score: 0.3509 - val_loss: 0.7481 - val_iou_score: 0.2349
# Epoch 12/300
# 100/100 [==============================] - 82s 815ms/step - loss: 0.5861 - iou_score: 0.3510 - val_loss: 0.7457 - val_iou_score: 0.2364
# Epoch 13/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5861 - iou_score: 0.3510 - val_loss: 0.7464 - val_iou_score: 0.2363
# Epoch 14/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5861 - iou_score: 0.3510 - val_loss: 0.7462 - val_iou_score: 0.2363
# Epoch 15/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5860 - iou_score: 0.3511 - val_loss: 0.7471 - val_iou_score: 0.2354
# Epoch 16/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5860 - iou_score: 0.3511 - val_loss: 0.7468 - val_iou_score: 0.2360
# Epoch 17/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5859 - iou_score: 0.3511 - val_loss: 0.7473 - val_iou_score: 0.2357
# Epoch 18/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5859 - iou_score: 0.3512 - val_loss: 0.7461 - val_iou_score: 0.2362
# Epoch 19/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5858 - iou_score: 0.3512 - val_loss: 0.7464 - val_iou_score: 0.2360
# Epoch 20/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5858 - iou_score: 0.3513 - val_loss: 0.7469 - val_iou_score: 0.2359
# Epoch 21/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5857 - iou_score: 0.3513 - val_loss: 0.7455 - val_iou_score: 0.2363
# Epoch 22/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5857 - iou_score: 0.3513 - val_loss: 0.7471 - val_iou_score: 0.2361
# Epoch 23/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.
300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5845 - iou_score: 0.3524 - val_loss: 0.7496 - val_iou_score: 0.2342
# Epoch 54/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5844 - iou_score: 0.3525 - val_loss: 0.7473 - val_iou_score: 0.2356
# Epoch 55/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5844 - iou_score: 0.3525 - val_loss: 0.7476 - val_iou_score: 0.2353
# Epoch 56/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5844 - iou_score: 0.3525 - val_loss: 0.7498 - val_iou_score: 0.2345
# Epoch 57/300
# 100/100 [==============================] - 83s 833ms/step - loss: 0.5843 - iou_score: 0.3525 - val_loss: 0.7498 - val_iou_score: 0.2341
# Epoch 58/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5843 - iou_score: 0.3526 - val_loss: 0.7494 - val_iou_score: 0.2349
# Epoch 59/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5842 - iou_score: 0.3526 - val_loss: 0.7500 - val_iou_score: 0.2340
# Epoch 60/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5842 - iou_score: 0.3527 - val_loss: 0.7482 - val_iou_score: 0.2351
# Epoch 61/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5842 - iou_score: 0.3527 - val_loss: 0.7506 - val_iou_score: 0.2338
# Epoch 62/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5841 - iou_score: 0.3527 - val_loss: 0.7499 - val_iou_score: 0.2341
# Epoch 63/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5841 - iou_score: 0.3528 - val_loss: 0.7488 - val_iou_score: 0.2348
# Epoch 64/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5841 - iou_score: 0.3528 - val_loss: 0.7502 - val_iou_score: 0.2341
# Epoch 65/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5840 - iou_score: 0.3528 - val_loss: 0.7494 - val_iou_score: 0.2348
# Epoch 66/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5840 - iou_score: 0.3528 - val_loss: 0.7484 - val_iou_score: 0.2352
# Epoch 67/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5839 - iou_score: 0.3529 - val_loss: 0.7505 - val_iou_score: 0.2340
# Epoch 68/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5839 - iou_score: 0.3529 - val_loss: 0.7510 - val_iou_score: 0.2339
# Epoch 69/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5838 - iou_score: 0.3530 - val_loss: 0.7484 - val_iou_score: 0.2353
# Epoch 70/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5838 - iou_score: 0.3530 - val_loss: 0.7497 - val_iou_score: 0.2344
# Epoch 71/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5838 - iou_score: 0.3530 - val_loss: 0.7497 - val_iou_score: 0.2346
# Epoch 72/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5837 - iou_score: 0.3531 - val_loss: 0.7503 - val_iou_score: 0.2341
# Epoch 73/300
# 100/100 [==============================] - 83s 830ms/step - loss: 0.5837 - iou_score: 0.3531 - val_loss: 0.7485 - val_iou_score: 0.2353
# Epoch 74/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5837 - iou_score: 0.3531 - val_loss: 0.7522 - val_iou_score: 0.2329
# Epoch 75/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5836 - iou_score: 0.3532 - val_loss: 0.7502 - val_iou_score: 0.2341
# Epoch 76/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5836 - iou_score: 0.3532 - val_loss: 0.7485 - val_iou_score: 0.2349
# Epoch 77/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5836 - iou_score: 0.3532 - val_loss: 0.7492 - val_iou_score: 0.2349
# Epoch 78/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5835 - iou_score: 0.3532 - val_loss: 0.7505 - val_iou_score: 0.2341
# Epoch 79/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5835 - iou_score: 0.3533 - val_loss: 0.7521 - val_iou_score: 0.2335
# Epoch 80/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5835 - iou_score: 0.3533 - val_loss: 0.7512 - val_iou_score: 0.2334
# Epoch 81/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5834 - iou_score: 0.3533 - val_loss: 0.7484 - val_iou_score: 0.2355
# Epoch 82/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5834 - iou_score: 0.3534 - val_loss: 0.7521 - val_iou_score: 0.2331
# Epoch 83/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5833 - iou_score: 0.3534 - val_loss: 0.7502 - val_iou_score: 0.2343
# Epoch 84/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5833 - iou_score: 0.3534 - val_loss: 0.7488 - val_iou_score: 0.2354
# Epoch 85/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5833 - iou_score: 0.3535 - val_loss: 0.7502 - val_iou_score: 0.2341
# Epoch 86/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5832 - iou_score: 0.3535 - val_loss: 0.7504 - val_iou_score: 0.2341
# Epoch 87/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5832 - iou_score: 0.3536 - val_loss: 0.7499 - val_iou_score: 0.2346
# Epoch 88/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5832 - iou_score: 0.3536 - val_loss: 0.7513 - val_iou_score: 0.2339
# Epoch 89/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5832 - iou_score: 0.3535 - val_loss: 0.7473 - val_iou_score: 0.2362
# Epoch 90/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5831 - iou_score: 0.3536 - val_loss: 0.7499 - val_iou_score: 0.2345
# Epoch 91/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5831 - iou_score: 0.3537 - val_loss: 0.7538 - val_iou_score: 0.2322
# Epoch 92/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5830 - iou_score: 0.3537 - val_loss: 0.7520 - val_iou_score: 0.2333
# Epoch 93/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5830 - iou_score: 0.3537 - val_loss: 0.7501 - val_iou_score: 0.2343
# Epoch 94/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5829 - iou_score: 0.3537 - val_loss: 0.7536 - val_iou_score: 0.2323
# Epoch 95/300
# 100/100 [==============================] - 82s 816ms/step - loss: 0.5829 - iou_score: 0.3538 - val_loss: 0.7526 - val_iou_score: 0.2325
# Epoch 96/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5828 - iou_score: 0.3538 - val_loss: 0.7491 - val_iou_score: 0.2354
# Epoch 97/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5828 - iou_score: 0.3539 - val_loss: 0.7536 - val_iou_score: 0.2328
# Epoch 98/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5828 - iou_score: 0.3539 - val_loss: 0.7505 - val_iou_score: 0.2342
# Epoch 99/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5828 - iou_score: 0.3539 - val_loss: 0.7496 - val_iou_score: 0.2347
# Epoch 100/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5827 - iou_score: 0.3540 - val_loss: 0.7518 - val_iou_score: 0.2335
# Epoch 101/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5827 - iou_score: 0.3540 - val_loss: 0.7503 - val_iou_score: 0.2346
# Epoch 102/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5827 - iou_score: 0.3540 - val_loss: 0.7495 - val_iou_score: 0.2350
# Epoch 103/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5826 - iou_score: 0.3540 - val_loss: 0.7507 - val_iou_score: 0.2343
# Epoch 104/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5826 - iou_score: 0.3541 - val_loss: 0.7514 - val_iou_score: 0.2336
# Epoch 105/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5825 - iou_score: 0.3542 - val_loss: 0.7490 - val_iou_score: 0.2352
# Epoch 106/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5825 - iou_score: 0.3541 - val_loss: 0.7501 - val_iou_score: 0.2346
# Epoch 107/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5825 - iou_score: 0.3542 - val_loss: 0.7499 - val_iou_score: 0.2346
# Epoch 108/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5824 - iou_score: 0.3542 - val_loss: 0.7522 - val_iou_score: 0.2331
# Epoch 109/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5824 - iou_score: 0.3542 - val_loss: 0.7524 - val_iou_score: 0.2329
# Epoch 110/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5824 - iou_score: 0.3542 - val_loss: 0.7536 - val_iou_score: 0.2322
# Epoch 111/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5823 - iou_score: 0.3543 - val_loss: 0.7515 - val_iou_score: 0.2333
# Epoch 112/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5823 - iou_score: 0.3543 - val_loss: 0.7528 - val_iou_score: 0.2327
# Epoch 113/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5823 - iou_score: 0.3544 - val_loss: 0.7508 - val_iou_score: 0.2342
# Epoch 114/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5823 - iou_score: 0.3544 - val_loss: 0.7519 - val_iou_score: 0.2332
# Epoch 115/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5822 - iou_score: 0.3544 - val_loss: 0.7534 - val_iou_score: 0.2324
# Epoch 116/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5821 - iou_score: 0.3544 - val_loss: 0.7519 - val_iou_score: 0.2332
# Epoch 117/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5821 - iou_score: 0.3545 - val_loss: 0.7510 - val_iou_score: 0.2343
# Epoch 118/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5821 - iou_score: 0.3545 - val_loss: 0.7508 - val_iou_score: 0.2341
# Epoch 119/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5821 - iou_score: 0.3545 - val_loss: 0.7541 - val_iou_score: 0.2323
# Epoch 120/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5821 - iou_score: 0.3545 - val_loss: 0.7529 - val_iou_score: 0.2329
# Epoch 121/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5820 - iou_score: 0.3546 - val_loss: 0.7511 - val_iou_score: 0.2338
# Epoch 122/300
# 100/100 [==============================] - 82s 816ms/step - loss: 0.5820 - iou_score: 0.3546 - val_loss: 0.7528 - val_iou_score: 0.2330
# Epoch 123/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5819 - iou_score: 0.3546 - val_loss: 0.7509 - val_iou_score: 0.2341
# Epoch 124/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5819 - iou_score: 0.3547 - val_loss: 0.7529 - val_iou_score: 0.2330
# Epoch 125/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5819 - iou_score: 0.3547 - val_loss: 0.7507 - val_iou_score: 0.2343
# Epoch 126/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5818 - iou_score: 0.3547 - val_loss: 0.7502 - val_iou_score: 0.2345
# Epoch 127/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5818 - iou_score: 0.3547 - val_loss: 0.7511 - val_iou_score: 0.2343
# Epoch 128/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5818 - iou_score: 0.3548 - val_loss: 0.7524 - val_iou_score: 0.2333
# Epoch 129/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5818 - iou_score: 0.3548 - val_loss: 0.7528 - val_iou_score: 0.2333
# Epoch 130/300
# 100/100 [==============================] - 81s 815ms/step - loss: 0.5817 - iou_score: 0.3549 - val_loss: 0.7530 - val_iou_score: 0.2327
# Epoch 131/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5817 - iou_score: 0.3548 - val_loss: 0.7521 - val_iou_score: 0.2333
# Epoch 132/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5816 - iou_score: 0.3549 - val_loss: 0.7535 - val_iou_score: 0.2323
# Epoch 133/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5816 - iou_score: 0.3549 - val_loss: 0.7517 - val_iou_score: 0.2338
# Epoch 134/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5816 - iou_score: 0.3549 - val_loss: 0.7525 - val_iou_score: 0.2332
# Epoch 135/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5816 - iou_score: 0.3550 - val_loss: 0.7537 - val_iou_score: 0.2321
# Epoch 136/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5815 - iou_score: 0.3550 - val_loss: 0.7533 - val_iou_score: 0.2329
# Epoch 137/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5815 - iou_score: 0.3550 - val_loss: 0.7550 - val_iou_score: 0.2318
# Epoch 138/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5814 - iou_score: 0.3551 - val_loss: 0.7525 - val_iou_score: 0.2332
# Epoch 139/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5814 - iou_score: 0.3551 - val_loss: 0.7538 - val_iou_score: 0.2325
# Epoch 140/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5814 - iou_score: 0.3551 - val_loss: 0.7546 - val_iou_score: 0.2319
# Epoch 141/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5814 - iou_score: 0.3552 - val_loss: 0.7542 - val_iou_score: 0.2324
# Epoch 142/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5814 - iou_score: 0.3551 - val_loss: 0.7522 - val_iou_score: 0.2331
# Epoch 143/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5813 - iou_score: 0.3552 - val_loss: 0.7514 - val_iou_score: 0.2337
# Epoch 144/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5813 - iou_score: 0.3552 - val_loss: 0.7554 - val_iou_score: 0.2313
# Epoch 145/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5812 - iou_score: 0.3553 - val_loss: 0.7532 - val_iou_score: 0.2328
# Epoch 146/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5812 - iou_score: 0.3553 - val_loss: 0.7544 - val_iou_score: 0.2322
# Epoch 147/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5812 - iou_score: 0.3553 - val_loss: 0.7544 - val_iou_score: 0.2323
# Epoch 148/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5811 - iou_score: 0.3554 - val_loss: 0.7542 - val_iou_score: 0.2321
# Epoch 149/300
# 100/100 [==============================] - 82s 818ms/step - loss: 0.5811 - iou_score: 0.3554 - val_loss: 0.7550 - val_iou_score: 0.2318
# Epoch 150/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5811 - iou_score: 0.3554 - val_loss: 0.7549 - val_iou_score: 0.2320
# Epoch 151/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5810 - iou_score: 0.3555 - val_loss: 0.7534 - val_iou_score: 0.2328
# Epoch 152/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5810 - iou_score: 0.3554 - val_loss: 0.7542 - val_iou_score: 0.2324
# Epoch 153/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5809 - iou_score: 0.3555 - val_loss: 0.7527 - val_iou_score: 0.2331
# Epoch 154/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5810 - iou_score: 0.3555 - val_loss: 0.7528 - val_iou_score: 0.2331
# Epoch 155/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5809 - iou_score: 0.3556 - val_loss: 0.7537 - val_iou_score: 0.2322
# Epoch 156/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5809 - iou_score: 0.3555 - val_loss: 0.7550 - val_iou_score: 0.2319
# Epoch 157/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5808 - iou_score: 0.3556 - val_loss: 0.7546 - val_iou_score: 0.2321
# Epoch 158/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5808 - iou_score: 0.3556 - val_loss: 0.7535 - val_iou_score: 0.2329
# Epoch 159/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5808 - iou_score: 0.3556 - val_loss: 0.7552 - val_iou_score: 0.2315
# Epoch 160/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5808 - iou_score: 0.3557 - val_loss: 0.7537 - val_iou_score: 0.2329
# Epoch 161/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5807 - iou_score: 0.3557 - val_loss: 0.7548 - val_iou_score: 0.2316
# Epoch 162/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5807 - iou_score: 0.3557 - val_loss: 0.7548 - val_iou_score: 0.2320
# Epoch 163/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5807 - iou_score: 0.3557 - val_loss: 0.7522 - val_iou_score: 0.2333
# Epoch 164/300
# 100/100 [==============================] - 83s 829ms/step - loss: 0.5806 - iou_score: 0.3558 - val_loss: 0.7559 - val_iou_score: 0.2313
# Epoch 165/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5806 - iou_score: 0.3558 - val_loss: 0.7555 - val_iou_score: 0.2317
# Epoch 166/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5806 - iou_score: 0.3558 - val_loss: 0.7560 - val_iou_score: 0.2308
# Epoch 167/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5805 - iou_score: 0.3559 - val_loss: 0.7545 - val_iou_score: 0.2325
# Epoch 168/300
# 100/100 [==============================] - 82s 817ms/step - loss: 0.5805 - iou_score: 0.3559 - val_loss: 0.7523 - val_iou_score: 0.2339
# Epoch 169/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5805 - iou_score: 0.3559 - val_loss: 0.7564 - val_iou_score: 0.2309
# Epoch 170/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5805 - iou_score: 0.3559 - val_loss: 0.7559 - val_iou_score: 0.2312
# Epoch 171/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5805 - iou_score: 0.3559 - val_loss: 0.7541 - val_iou_score: 0.2327
# Epoch 172/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5804 - iou_score: 0.3560 - val_loss: 0.7541 - val_iou_score: 0.2324
# Epoch 173/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5803 - iou_score: 0.3560 - val_loss: 0.7531 - val_iou_score: 0.2329
# Epoch 174/300
# 100/100 [==============================] - 84s 840ms/step - loss: 0.5803 - iou_score: 0.3560 - val_loss: 0.7557 - val_iou_score: 0.2319
# Epoch 175/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5803 - iou_score: 0.3561 - val_loss: 0.7546 - val_iou_score: 0.2321
# Epoch 176/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5803 - iou_score: 0.3561 - val_loss: 0.7550 - val_iou_score: 0.2317
# Epoch 177/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5802 - iou_score: 0.3561 - val_loss: 0.7573 - val_iou_score: 0.2307
# Epoch 178/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5802 - iou_score: 0.3562 - val_loss: 0.7561 - val_iou_score: 0.2313
# Epoch 179/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5802 - iou_score: 0.3561 - val_loss: 0.7531 - val_iou_score: 0.2330
# Epoch 180/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5802 - iou_score: 0.3562 - val_loss: 0.7554 - val_iou_score: 0.2317
# Epoch 181/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5801 - iou_score: 0.3562 - val_loss: 0.7534 - val_iou_score: 0.2331
# Epoch 182/300
# 100/100 [==============================] - 84s 841ms/step - loss: 0.5801 - iou_score: 0.3563 - val_loss: 0.7550 - val_iou_score: 0.2319
# Epoch 183/300
# 100/100 [==============================] - 83s 834ms/step - loss: 0.5801 - iou_score: 0.3563 - val_loss: 0.7583 - val_iou_score: 0.2301
# Epoch 184/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5801 - iou_score: 0.3563 - val_loss: 0.7526 - val_iou_score: 0.2335
# Epoch 185/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5800 - iou_score: 0.3564 - val_loss: 0.7557 - val_iou_score: 0.2314
# Epoch 186/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5800 - iou_score: 0.3563 - val_loss: 0.7564 - val_iou_score: 0.2312
# Epoch 187/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5800 - iou_score: 0.3564 - val_loss: 0.7564 - val_iou_score: 0.2311
# Epoch 188/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5800 - iou_score: 0.3564 - val_loss: 0.7564 - val_iou_score: 0.2314
# Epoch 189/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5798 - iou_score: 0.3565 - val_loss: 0.7554 - val_iou_score: 0.2319
# Epoch 190/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5799 - iou_score: 0.3564 - val_loss: 0.7530 - val_iou_score: 0.2335
# Epoch 191/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5799 - iou_score: 0.3564 - val_loss: 0.7550 - val_iou_score: 0.2316
# Epoch 192/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5798 - iou_score: 0.3565 - val_loss: 0.7551 - val_iou_score: 0.2319
# Epoch 193/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5798 - iou_score: 0.3565 - val_loss: 0.7548 - val_iou_score: 0.2319
# Epoch 194/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5798 - iou_score: 0.3565 - val_loss: 0.7563 - val_iou_score: 0.2312
# Epoch 195/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5796 - iou_score: 0.3566 - val_loss: 0.7549 - val_iou_score: 0.2320
# Epoch 196/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5797 - iou_score: 0.3566 - val_loss: 0.7568 - val_iou_score: 0.2307
# Epoch 197/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5797 - iou_score: 0.3566 - val_loss: 0.7560 - val_iou_score: 0.2316
# Epoch 198/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5796 - iou_score: 0.3567 - val_loss: 0.7583 - val_iou_score: 0.2300
# Epoch 199/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5796 - iou_score: 0.3567 - val_loss: 0.7552 - val_iou_score: 0.2325
# Epoch 200/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5796 - iou_score: 0.3567 - val_loss: 0.7571 - val_iou_score: 0.2310
# Epoch 201/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5796 - iou_score: 0.3567 - val_loss: 0.7566 - val_iou_score: 0.2313
# Epoch 202/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5795 - iou_score: 0.3568 - val_loss: 0.7576 - val_iou_score: 0.2307
# Epoch 203/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5795 - iou_score: 0.3568 - val_loss: 0.7562 - val_iou_score: 0.2313
# Epoch 204/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5795 - iou_score: 0.3568 - val_loss: 0.7552 - val_iou_score: 0.2321
# Epoch 205/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5794 - iou_score: 0.3568 - val_loss: 0.7539 - val_iou_score: 0.2325
# Epoch 206/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5794 - iou_score: 0.3569 - val_loss: 0.7564 - val_iou_score: 0.2308
# Epoch 207/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5794 - iou_score: 0.3569 - val_loss: 0.7547 - val_iou_score: 0.2326
# Epoch 208/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5794 - iou_score: 0.3569 - val_loss: 0.7553 - val_iou_score: 0.2319
# Epoch 209/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5793 - iou_score: 0.3569 - val_loss: 0.7555 - val_iou_score: 0.2320
# Epoch 210/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5793 - iou_score: 0.3569 - val_loss: 0.7577 - val_iou_score: 0.2306
# Epoch 211/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5793 - iou_score: 0.3570 - val_loss: 0.7537 - val_iou_score: 0.2326
# Epoch 212/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5793 - iou_score: 0.3570 - val_loss: 0.7575 - val_iou_score: 0.2306
# Epoch 213/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5792 - iou_score: 0.3571 - val_loss: 0.7581 - val_iou_score: 0.2303
# Epoch 214/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5792 - iou_score: 0.3570 - val_loss: 0.7550 - val_iou_score: 0.2327
# Epoch 215/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5792 - iou_score: 0.3570 - val_loss: 0.7564 - val_iou_score: 0.2314
# Epoch 216/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5791 - iou_score: 0.3572 - val_loss: 0.7562 - val_iou_score: 0.2314
# Epoch 217/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5791 - iou_score: 0.3571 - val_loss: 0.7575 - val_iou_score: 0.2307
# Epoch 218/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5791 - iou_score: 0.3571 - val_loss: 0.7555 - val_iou_score: 0.2319
# Epoch 219/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5790 - iou_score: 0.3572 - val_loss: 0.7564 - val_iou_score: 0.2313
# Epoch 220/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5790 - iou_score: 0.3572 - val_loss: 0.7587 - val_iou_score: 0.2299
# Epoch 221/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5790 - iou_score: 0.3572 - val_loss: 0.7570 - val_iou_score: 0.2308
# Epoch 222/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5790 - iou_score: 0.3572 - val_loss: 0.7564 - val_iou_score: 0.2313
# Epoch 223/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5789 - iou_score: 0.3573 - val_loss: 0.7562 - val_iou_score: 0.2312
# Epoch 224/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5789 - iou_score: 0.3573 - val_loss: 0.7537 - val_iou_score: 0.2325
# Epoch 225/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5789 - iou_score: 0.3573 - val_loss: 0.7560 - val_iou_score: 0.2314
# Epoch 226/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5789 - iou_score: 0.3573 - val_loss: 0.7582 - val_iou_score: 0.2303
# Epoch 227/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5788 - iou_score: 0.3574 - val_loss: 0.7577 - val_iou_score: 0.2309
# Epoch 228/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5788 - iou_score: 0.3574 - val_loss: 0.7568 - val_iou_score: 0.2310
# Epoch 229/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5788 - iou_score: 0.3573 - val_loss: 0.7573 - val_iou_score: 0.2306
# Epoch 230/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5787 - iou_score: 0.3574 - val_loss: 0.7576 - val_iou_score: 0.2307
# Epoch 231/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5787 - iou_score: 0.3575 - val_loss: 0.7568 - val_iou_score: 0.2310
# Epoch 232/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5787 - iou_score: 0.3575 - val_loss: 0.7575 - val_iou_score: 0.2311
# Epoch 233/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5787 - iou_score: 0.3575 - val_loss: 0.7576 - val_iou_score: 0.2308
# Epoch 234/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5786 - iou_score: 0.3575 - val_loss: 0.7572 - val_iou_score: 0.2311
# Epoch 235/300
# 100/100 [==============================] - 82s 819ms/step - loss: 0.5786 - iou_score: 0.3576 - val_loss: 0.7588 - val_iou_score: 0.2300
# Epoch 236/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5786 - iou_score: 0.3575 - val_loss: 0.7574 - val_iou_score: 0.2310
# Epoch 237/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5785 - iou_score: 0.3576 - val_loss: 0.7575 - val_iou_score: 0.2308
# Epoch 238/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5785 - iou_score: 0.3576 - val_loss: 0.7572 - val_iou_score: 0.2312
# Epoch 239/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5785 - iou_score: 0.3576 - val_loss: 0.7593 - val_iou_score: 0.2298
# Epoch 240/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5785 - iou_score: 0.3576 - val_loss: 0.7570 - val_iou_score: 0.2309
# Epoch 241/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5784 - iou_score: 0.3577 - val_loss: 0.7580 - val_iou_score: 0.2305
# Epoch 242/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5784 - iou_score: 0.3577 - val_loss: 0.7584 - val_iou_score: 0.2303
# Epoch 243/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5784 - iou_score: 0.3577 - val_loss: 0.7578 - val_iou_score: 0.2303
# Epoch 244/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5784 - iou_score: 0.3578 - val_loss: 0.7580 - val_iou_score: 0.2306
# Epoch 245/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5784 - iou_score: 0.3577 - val_loss: 0.7570 - val_iou_score: 0.2313
# Epoch 246/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5783 - iou_score: 0.3578 - val_loss: 0.7588 - val_iou_score: 0.2299
# Epoch 247/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5783 - iou_score: 0.3578 - val_loss: 0.7600 - val_iou_score: 0.2292
# Epoch 248/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5782 - iou_score: 0.3579 - val_loss: 0.7581 - val_iou_score: 0.2302
# Epoch 249/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5782 - iou_score: 0.3579 - val_loss: 0.7590 - val_iou_score: 0.2303
# Epoch 250/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5782 - iou_score: 0.3579 - val_loss: 0.7600 - val_iou_score: 0.2293
# Epoch 251/300
# 100/100 [==============================] - 83s 825ms/step - loss: 0.5782 - iou_score: 0.3579 - val_loss: 0.7580 - val_iou_score: 0.2310
# Epoch 252/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5781 - iou_score: 0.3579 - val_loss: 0.7590 - val_iou_score: 0.2298
# Epoch 253/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5781 - iou_score: 0.3579 - val_loss: 0.7577 - val_iou_score: 0.2309
# Epoch 254/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5781 - iou_score: 0.3580 - val_loss: 0.7556 - val_iou_score: 0.2322
# Epoch 255/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5781 - iou_score: 0.3580 - val_loss: 0.7566 - val_iou_score: 0.2315
# Epoch 256/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5780 - iou_score: 0.3580 - val_loss: 0.7573 - val_iou_score: 0.2312
# Epoch 257/300
# 100/100 [==============================] - 82s 825ms/step - loss: 0.5780 - iou_score: 0.3581 - val_loss: 0.7571 - val_iou_score: 0.2311
# Epoch 258/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5780 - iou_score: 0.3581 - val_loss: 0.7582 - val_iou_score: 0.2310
# Epoch 259/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5780 - iou_score: 0.3581 - val_loss: 0.7591 - val_iou_score: 0.2299
# Epoch 260/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5779 - iou_score: 0.3581 - val_loss: 0.7590 - val_iou_score: 0.2296
# Epoch 261/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5779 - iou_score: 0.3581 - val_loss: 0.7578 - val_iou_score: 0.2310
# Epoch 262/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5779 - iou_score: 0.3582 - val_loss: 0.7573 - val_iou_score: 0.2310
# Epoch 263/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5778 - iou_score: 0.3582 - val_loss: 0.7575 - val_iou_score: 0.2306
# Epoch 264/300
# 100/100 [==============================] - 82s 824ms/step - loss: 0.5778 - iou_score: 0.3582 - val_loss: 0.7593 - val_iou_score: 0.2301
# Epoch 265/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5778 - iou_score: 0.3583 - val_loss: 0.7583 - val_iou_score: 0.2301
# Epoch 266/300
# 100/100 [==============================] - 83s 829ms/step - loss: 0.5778 - iou_score: 0.3583 - val_loss: 0.7569 - val_iou_score: 0.2317
# Epoch 267/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5777 - iou_score: 0.3583 - val_loss: 0.7570 - val_iou_score: 0.2312
# Epoch 268/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5778 - iou_score: 0.3583 - val_loss: 0.7583 - val_iou_score: 0.2306
# Epoch 269/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5777 - iou_score: 0.3583 - val_loss: 0.7600 - val_iou_score: 0.2293
# Epoch 270/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5777 - iou_score: 0.3584 - val_loss: 0.7581 - val_iou_score: 0.2308
# Epoch 271/300
# 100/100 [==============================] - 83s 829ms/step - loss: 0.5777 - iou_score: 0.3584 - val_loss: 0.7612 - val_iou_score: 0.2288
# Epoch 272/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5776 - iou_score: 0.3584 - val_loss: 0.7581 - val_iou_score: 0.2310
# Epoch 273/300
# 100/100 [==============================] - 83s 830ms/step - loss: 0.5776 - iou_score: 0.3584 - val_loss: 0.7548 - val_iou_score: 0.2325
# Epoch 274/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5776 - iou_score: 0.3585 - val_loss: 0.7588 - val_iou_score: 0.2304
# Epoch 275/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5775 - iou_score: 0.3585 - val_loss: 0.7611 - val_iou_score: 0.2285
# Epoch 276/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5776 - iou_score: 0.3585 - val_loss: 0.7606 - val_iou_score: 0.2293
# Epoch 277/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5775 - iou_score: 0.3585 - val_loss: 0.7613 - val_iou_score: 0.2291
# Epoch 278/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5775 - iou_score: 0.3586 - val_loss: 0.7588 - val_iou_score: 0.2308
# Epoch 279/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5775 - iou_score: 0.3585 - val_loss: 0.7600 - val_iou_score: 0.2297
# Epoch 280/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5774 - iou_score: 0.3586 - val_loss: 0.7611 - val_iou_score: 0.2285
# Epoch 281/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5774 - iou_score: 0.3586 - val_loss: 0.7591 - val_iou_score: 0.2302
# Epoch 282/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5774 - iou_score: 0.3586 - val_loss: 0.7601 - val_iou_score: 0.2296
# Epoch 283/300
# 100/100 [==============================] - 83s 831ms/step - loss: 0.5773 - iou_score: 0.3586 - val_loss: 0.7591 - val_iou_score: 0.2307
# Epoch 284/300
# 100/100 [==============================] - 82s 821ms/step - loss: 0.5773 - iou_score: 0.3587 - val_loss: 0.7592 - val_iou_score: 0.2298
# Epoch 285/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5773 - iou_score: 0.3587 - val_loss: 0.7591 - val_iou_score: 0.2300
# Epoch 286/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5772 - iou_score: 0.3587 - val_loss: 0.7590 - val_iou_score: 0.2300
# Epoch 287/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5772 - iou_score: 0.3587 - val_loss: 0.7596 - val_iou_score: 0.2297
# Epoch 288/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5772 - iou_score: 0.3587 - val_loss: 0.7608 - val_iou_score: 0.2293
# Epoch 289/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5772 - iou_score: 0.3588 - val_loss: 0.7587 - val_iou_score: 0.2305
# Epoch 290/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5772 - iou_score: 0.3587 - val_loss: 0.7605 - val_iou_score: 0.2291
# Epoch 291/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5772 - iou_score: 0.3588 - val_loss: 0.7607 - val_iou_score: 0.2291
# Epoch 292/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5772 - iou_score: 0.3588 - val_loss: 0.7609 - val_iou_score: 0.2287
# Epoch 293/300
# 100/100 [==============================] - 83s 827ms/step - loss: 0.5771 - iou_score: 0.3589 - val_loss: 0.7596 - val_iou_score: 0.2295
# Epoch 294/300
# 100/100 [==============================] - 82s 820ms/step - loss: 0.5771 - iou_score: 0.3588 - val_loss: 0.7579 - val_iou_score: 0.2306
# Epoch 295/300
# 100/100 [==============================] - 83s 829ms/step - loss: 0.5771 - iou_score: 0.3589 - val_loss: 0.7597 - val_iou_score: 0.2294
# Epoch 296/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5770 - iou_score: 0.3589 - val_loss: 0.7593 - val_iou_score: 0.2300
# Epoch 297/300
# 100/100 [==============================] - 83s 826ms/step - loss: 0.5770 - iou_score: 0.3589 - val_loss: 0.7611 - val_iou_score: 0.2291
# Epoch 298/300
# 100/100 [==============================] - 83s 828ms/step - loss: 0.5770 - iou_score: 0.3590 - val_loss: 0.7607 - val_iou_score: 0.2293
# Epoch 299/300
# 100/100 [==============================] - 82s 823ms/step - loss: 0.5770 - iou_score: 0.3590 - val_loss: 0.7606 - val_iou_score: 0.2295
# Epoch 300/300
# 100/100 [==============================] - 82s 822ms/step - loss: 0.5769 - iou_score: 0.3590 - val_loss: 0.7619 - val_iou_score: 0.2284

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
for i,m in zip(X_test[:10],y_test[:10]):
    #original image
    image = cv2.imread(i, cv2.IMREAD_UNCHANGED)
    image = cv2.resize(image, (256,256)) 
    
    #predicted segmentation map
    predicted  = model.predict(image[np.newaxis,:,:,:])
    
    #original segmentation map
    image_mask = cv2.imread(m, cv2.IMREAD_UNCHANGED)
    print(m)
    image_mask = cv2.resize(image_mask, (256,256))

    plt.figure(figsize=(10,6))
    plt.subplot(131)
    plt.imshow(image)
    plt.subplot(132)
    plt.imshow(image_mask)
    plt.subplot(133)
    plt.imshow(predicted[0,:,:,0], cmap='gray', vmax=1, vmin=0)
    plt.show()
# Out:
# data/output/275/frame10480_gtFine_polygons.png
# data/output/327/frame1124_gtFine_polygons.png
# data/output/400/frame0595_gtFine_polygons.png
# data/output/361/frame8692_gtFine_polygons.png
# data/output/357/frame27932_gtFine_polygons.png
# data/output/263/frame19513_gtFine_polygons.png
# data/output/233/frame1002_gtFine_polygons.png
# data/output/213/frame18369_gtFine_polygons.png
# data/output/377/frame15853_gtFine_polygons.png
# data/output/387/frame5281_gtFine_polygons.png
